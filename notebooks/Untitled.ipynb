# %%
import numpy as np

lrnp.load('/homes/cv300/Documents/scattering/lr_history.npy')[:, 0]
np.load('/homes/cv300/Documents/scattering/val_acc.npy')
# Out:
# array([[0.00000000e+00],
#        [0.00000000e+00],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
#        [4.88281250e-05],
# ...
