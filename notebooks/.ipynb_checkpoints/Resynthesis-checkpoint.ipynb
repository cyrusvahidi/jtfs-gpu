# %%
import numpy as np
from scipy.io import wavfile
import matplotlib.pyplot as plt
import torch
import resampy
import librosa

from torch.autograd import backward
from kymatio.torch import TimeFrequencyScattering1D

from utils import generate_harmonic_signal, chirp

SAMPLE_RATE = 22050

# %% [markdown]
# ### Create the filterbank

# %%
N = 2**17
jtfs = TimeFrequencyScattering1D(
    J = 8, 
    shape = (N, ), 
    Q = 12, 
    T = None, 
    max_pad_factor=1,
    max_pad_factor_fr=1,
    average_fr = False,
).cuda()

# %% [markdown]
# ### Gradient Descent

# %%
import time

def reconstruct(x, 
                lr = 100, 
                n_iter = 200, 
                bold_driver_accelerator = 1.1, 
                bold_driver_brake = 0.55):
    start = time.time()

    err_history = []

    torch.manual_seed(0)
    noise = torch.randn((N,), requires_grad=True)
    S_noise = jtfs(noise.cuda())

    target = torch.from_numpy(x)
    S_target = jtfs(target.cuda())

    for i in range(n_iter):
        err = torch.norm(S_noise - S_target)

        if i % 10 == 0:
            print('Iteration %3d, loss %.2f' % (i, err.cpu().detach().numpy()))

        err_history.append(err)
        err.backward() # backward pass

        # gradient descent
        delta_y = noise.grad
        with torch.no_grad():
            noise_new = noise - lr * delta_y
        noise_new.requires_grad = True       

        if err_history[i] > err_history[i - 1]:
            lr *= bold_driver_brake
        else:
            lr *= bold_driver_accelerator
            noise = noise_new

        S_noise = jtfs(noise) # forward pass

    end = time.time()
    print(end-start)
    return target, noise

def plot_spectrograms(target, noise, Fs=22050):
    plt.figure(figsize=(8, 2))
    plt.plot(noise.detach().numpy())
    plt.title("Reconstructed signal")

    plt.figure(figsize=(8, 8))
    plt.specgram(target, Fs=Fs)
    plt.title("Spectrogram of original signal")

    plt.figure(figsize=(8, 8))
    plt.specgram(noise.detach().numpy(), Fs=Fs)
    plt.title("Spectrogram of reconstructed signal")

    plt.show()

# %% [markdown]
# ### Harmonic Signal

# %%
x = generate_harmonic_signal(N)
display(ipd.Audio(x, rate=SAMPLE_RATE, autoplay=True))

target, recon = reconstruct(x)
plot_spectrograms(target, recon)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Iteration   0, loss 472.07
# Iteration  10, loss 82.86
# Iteration  20, loss 59.76
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_137159/3313787849.py in <module>
#       2 display(ipd.Audio(x, rate=SAMPLE_RATE, autoplay=True))
#       3
# ----> 4 target, recon = reconstruct(x)
#       5 plot_spectrograms(target, recon)
#
# /tmp/ipykernel_137159/1959847946.py in reconstruct(x, lr, n_iter, bold_driver_accelerator, bold_driver_brake)
#      38             noise = noise_new
#      39
# ---> 40         S_noise = jtfs(noise) # forward pass
#      41
#      42     end = time.time()
#
# ~/venvs/dptm-wyn/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/venvs/dptm-wyn/lib/python3.8/site-packages/kymatio/frontend/torch_frontend.py in forward(self, x)
#      24         self.backend.input_checks(x)
#      25
# ---> 26         return self.scattering(x)
#      27
#      28     _doc_array = 'torch.Tensor'
#
# ~/venvs/dptm-wyn/lib/python3.8/site-packages/kymatio/scattering1d/frontend/torch_frontend.py in scattering(self, x)
#     247             x = x.to(device)
#     248
# --> 249         S = timefrequency_scattering1d(
#     250             x,
#     251             self.backend.pad, self.backend.unpad,
#
# ~/venvs/dptm-wyn/lib/python3.8/site-packages/kymatio/scattering1d/core/timefrequency_scattering1d.py in timefrequency_scattering1d(x, pad, unpad, backend, J, log2_T, psi1, psi2, phi, sc_freq, pad_fn, pad_left, pad_right, ind_start, ind_end, oversampling, oversampling_fr, aligned, average, average_global, average_global_phi, out_type, out_3D, out_exclude, pad_mode)
#     867             # `* psi_f` part of `U1 * (psi_t * psi_f)`
#     868             if not skip_spinned:
# --> 869                 _frequency_scattering(Y_2_hat, j2, n2, pad_fr, k1_plus_k2,
#     870                                       trim_tm, commons, out_S_2['psi_t * psi_f'])
#     871
#
# ~/venvs/dptm-wyn/lib/python3.8/site-packages/kymatio/scattering1d/core/timefrequency_scattering1d.py in _frequency_scattering(Y_2_hat, j2, n2, pad_fr, k1_plus_k2, trim_tm, commons, out_S_2, spin_down)
#     988             # Wavelet transform over frequency
#     989             Y_fr_c = B.cdgmm(Y_2_hat, psi1_f[n1_fr][subsample_equiv_due_to_pad])
# --> 990             Y_fr_hat = B.subsample_fourier(Y_fr_c, 2**n1_fr_subsample, axis=-2)
#     991             Y_fr_c = B.ifft(Y_fr_hat, axis=-2)
#     992
#
# ~/venvs/dptm-wyn/lib/python3.8/site-packages/kymatio/scattering1d/backend/torch_backend.py in subsample_fourier(cls, x, k, axis)
#      44
#      45         x = torch.view_as_real(x)
# ---> 46         res = x.view(s).mean(dim=axis)
#      47         res = torch.view_as_complex(res)
#      48
#
# KeyboardInterrupt:

# %% [markdown]
# ### Chirp Signal

# %%
x = chirp(2**17, 30, 400, fs=SAMPLE_RATE, method='exp')

display(ipd.Audio(x, rate=SAMPLE_RATE, autoplay=True))

target, recon = reconstruct(x)
plot_spectrograms(target, recon)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Iteration   0, loss 504.19
# Iteration  10, loss 54.36
# Iteration  20, loss 28.29
# Iteration  30, loss 22.71
# Iteration  40, loss 20.62
# Iteration  50, loss 19.47
# Iteration  60, loss 19.77
# Iteration  70, loss 18.18
# Iteration  80, loss 17.52
# Iteration  90, loss 17.03
# Iteration 100, loss 17.10
# Iteration 110, loss 16.42
# Iteration 120, loss 16.30
# Iteration 130, loss 16.13
# Iteration 140, loss 15.85
# Iteration 150, loss 15.72
# Iteration 160, loss 15.62
# Iteration 170, loss 15.50
# Iteration 180, loss 15.16
# Iteration 190, loss 15.06
# 89.3575165271759

# %%
display(ipd.Audio(recon.detach().numpy(), rate=SAMPLE_RATE, autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
